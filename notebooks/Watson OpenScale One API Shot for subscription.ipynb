# %% [markdown]
# <img src="https://github.com/pmservice/ai-openscale-tutorials/raw/master/notebooks/images/banner.png" align="left" alt="banner">

# %% [markdown]
# # One API call to configure SageMaker asset subscription

# %% [markdown]
# This notebook shows how to log the payload for the model deployed on custom model serving engine using AI OpenScale python sdk.

# %% [markdown]
# Contents
# - [1. Setup](#setup)
# - [2. Binding machine learning engine](#binding)
# - [3. Subscriptions](#subscription)
# - [4. Scoring and payload logging](#scoring)
# - [5. Feedback logging](#feedback)
# - [6. Data Mart](#datamart)

# %% [markdown]
# <a id="setup"></a>
# ## 1. Setup

# %% [markdown]
# Import and initiate.

# %%
# !pip install --upgrade ibm-ai-openscale --no-cache | tail -n 1
# Out:
# You are using pip version 9.0.1, however version 19.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already up-to-date: docutils>=0.10 in /Applications/anaconda/envs/python35/lib/python3.5/site-packages (from ibm-cos-sdk-core==2.*,>=2.0.0->ibm-cos-sdk->watson-machine-learning-client->ibm-ai-openscale)

# %%
import json
from ibm_ai_openscale import APIClient
from ibm_ai_openscale.supporting_classes import PayloadRecord
from ibm_ai_openscale.engines import *
from ibm_ai_openscale.utils import *

# %% [markdown]
# #### Let's define some constants required to set up data mart:
#
# - AIOS_CREDENTIALS
# - POSTGRES_CREDENTIALS
# - SCHEMA_NAME

# %%
AIOS_CREDENTIALS = {
  "url": "https://api.aiopenscale.cloud.ibm.com",
  "instance_guid": "***",
  "apikey": "***"
}

# %%
# The code was removed by Watson Studio for sharing.

# %%
POSTGRES_CREDENTIALS = {
    "db_type": "postgresql",
    "uri_cli_1": "xxx",
    "maps": [],
    "instance_administration_api": {
        "instance_id": "xxx",
        "root": "xxx",
        "deployment_id": "xxx"
    },
    "name": "xxx",
    "uri_cli": "xxx",
    "uri_direct_1": "xxx",
    "ca_certificate_base64": "xxx",
    "deployment_id": "xxx",
    "uri": "xxx"
}

# %%
# The code was removed by Watson Studio for sharing.

# %%
SCHEMA_NAME = 'data_mart_for_one_call'

# %% [markdown]
# Create schema for data mart.

# %%
create_postgres_schema(postgres_credentials=POSTGRES_CREDENTIALS, schema_name=SCHEMA_NAME)

# %%
client = APIClient(AIOS_CREDENTIALS)

# %%
client.version
# Out:
# '2.0.18'

# %% [markdown]
# ### 1.2 DataMart setup

# %%
client.data_mart.setup(db_credentials=POSTGRES_CREDENTIALS, schema=SCHEMA_NAME)
# Out:
# Warning during setup of data mart.
# Status code: 409, body: {"trace":"ZmYzMGNkYzktOWNlNi00YzNkLTk3MDQtYTRhYjBhN2E4NzI4","errors":[{"code":"AISCS0004W","message":"Data Mart with this id is already defined"}]}

# %% [markdown]
# <a id="binding"></a>
# ## 2. Bind machine learning engines

# %% [markdown]
# ### 2.1 Bind  `SageMaker` machine learning engine
#
# Provide credentials using following fields:
# - `access_key_id`
# - `secret_access_key`
# - `region`

# %%
SAGEMAKER_ENGINE_CREDENTIALS = {
        "access_key_id": "***",
        "secret_access_key": "***",
        "region": "***"
}

# %%
# The code was removed by Watson Studio for sharing.

# %%
binding_uid = client.data_mart.bindings.add('My SageMaker engine', SageMakerMachineLearningInstance(SAGEMAKER_ENGINE_CREDENTIALS))

# %%
client.data_mart.bindings.list()
# Out:
# <HTML>
#         <body>
#             <h3>Service bindings</h3>
#             <table style='border: 1px solid #dddddd; font-family: Courier'>
#                 <th style='border: 1px solid #dddddd'>uid</th><th style='border: 1px solid #dddddd'>name</th><th style='border: 1px solid #dddddd'>service_type</th><th style='border: 1px solid #dddddd'>created</th>
#                 <tr><td style='border: 1px solid #dddddd'>d47e97b7-07d7-4874-b604-e47ff1a0cd26</td><td style='border: 1px solid #dddddd'>My SageMaker engine</td><td style='border: 1px solid #dddddd'>amazon_sagemaker</td><td style='border: 1px solid #dddddd'>2019-02-14T12:50:02.856Z</td></tr><tr><td style='border: 1px solid #dddddd'>a73bf76d-a663-448a-b771-4f651f73d54e</td><td style='border: 1px solid #dddddd'>WML instance</td><td style='border: 1px solid #dddddd'>watson_machine_learning</td><td style='border: 1px solid #dddddd'>2019-02-13T10:34:55.751Z</td></tr><tr><td style='border: 1px solid #dddddd'>91d749e3-8551-45da-84fc-385e7ed2ba26</td><td style='border: 1px solid #dddddd'>My Azure ML Studio engine</td><td style='border: 1px solid #dddddd'>azure_machine_learning</td><td style='border: 1px solid #dddddd'>2019-02-07T12:44:20.125Z</td></tr>
#             </table>
#         </body>
#         </HTML>

# %% [markdown]
# <a id="subsciption"></a>
# ## 3. Subscriptions

# %% [markdown]
# ### 3.1 Load the configuration file content as dict

# %%
# !wget https://raw.githubusercontent.com/pmservice/ai-openscale-tutorials/master/assets/sagemaker_native_multiclass_breast-cancer_all_monitors_sub_configuration.json
# Out:
# --2019-02-14 14:05:50--  https://raw.githubusercontent.com/pmservice/ai-openscale-tutorials/master/assets/sagemaker_native_multiclass_breast-cancer_all_monitors_sub_configuration.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.48.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.48.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33498 (33K) [text/plain]
# Saving to: ‘sagemaker_native_multiclass_breast-cancer_all_monitors_sub_configuration.json’
#
# 100%[======================================>] 33,498      --.-K/s   in 0.002s
#
# 2019-02-14 14:05:50 (14.5 MB/s) - ‘sagemaker_native_multiclass_breast-cancer_all_monitors_sub_configuration.json’ saved [33498/33498]

# %%
configuration_file_path = 'sagemaker_native_multiclass_breast-cancer_all_monitors_sub_configuration.json'

with open(configuration_file_path, 'r') as fp:
    subscription_configuration = json.load(fp)

# %% [markdown]
# ### Preview the configuration file content

# %%
subscription_configuration
# Out:
# {'asset': {'asset_id': '0530ab0cd4f4dd5486b19c08df8b6914',
#   'asset_type': 'model',
#   'created_at': '2018-10-10T14:31:44.348Z',
#   'name': 'DEMO-multi-classification-2018-10-10-14-26-26',
#   'url': 's3://sagemaker-us-east-1-014862798213/sagemaker/DEMO-breast-cancer-prediction/DEMO-multi-classification-2018-10-10-14-26-26/output/model.tar.gz'},
#  'asset_properties': {'categorical_fields': [],
#   'feature_fields': ['radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'area_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'concavity_mean',
#    'concave points_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'radius_se',
#    'texture_se',
#    'perimeter_se',
#    'area_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'area_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'concavity_worst',
#    'concave points_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'],
#   'input_data_schema': {'fields': [{'metadata': {'modeling_role': 'feature'},
#      'name': 'radius_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'texture_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'perimeter_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'area_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'smoothness_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'compactness_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concavity_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concave points_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'symmetry_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'fractal_dimension_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'radius_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'texture_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'perimeter_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'area_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'smoothness_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'compactness_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concavity_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concave points_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'symmetry_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'fractal_dimension_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'radius_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'texture_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'perimeter_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'area_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'smoothness_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'compactness_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concavity_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concave points_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'symmetry_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'fractal_dimension_worst',
#      'nullable': True,
#      'type': 'double'}],
#    'type': 'struct'},
#   'input_data_type': 'structured',
#   'label_column': 'diagnosis',
#   'output_data_schema': {'fields': [{'metadata': {'modeling_role': 'feature'},
#      'name': 'radius_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'texture_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'perimeter_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'area_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'smoothness_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'compactness_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concavity_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concave points_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'symmetry_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'fractal_dimension_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'radius_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'texture_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'perimeter_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'area_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'smoothness_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'compactness_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concavity_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concave points_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'symmetry_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'fractal_dimension_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'radius_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'texture_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'perimeter_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'area_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'smoothness_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'compactness_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concavity_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concave points_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'symmetry_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'fractal_dimension_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'prediction'},
#      'name': 'predicted_label',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'probability'},
#      'name': 'score',
#      'nullable': True,
#      'type': {'containsNull': True,
#       'elementType': 'double',
#       'type': 'array'}}],
#    'type': 'struct'},
#   'prediction_field': 'predicted_label',
#   'prediction_probability_field': 'score',
#   'problem_type': 'multiclass',
#   'training_data_schema': {'fields': [{'metadata': {'modeling_role': 'feature'},
#      'name': 'radius_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'texture_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'perimeter_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'area_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'smoothness_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'compactness_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concavity_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concave points_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'symmetry_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'fractal_dimension_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'radius_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'texture_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'perimeter_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'area_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'smoothness_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'compactness_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concavity_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concave points_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'symmetry_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'fractal_dimension_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'radius_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'texture_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'perimeter_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'area_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'smoothness_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'compactness_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concavity_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concave points_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'symmetry_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'fractal_dimension_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'target'},
#      'name': 'diagnosis',
#      'nullable': True,
#      'type': 'double'}],
#    'type': 'struct'}},
#  'configurations': {'explainability': {'training_statistics': {'base_values': {'0': 13.37,
#      '1': 18.84,
#      '10': 0.3242,
#      '11': 1.1079999999999999,
#      '12': 2.287,
#      '13': 24.53,
#      '14': 0.006379999999999999,
#      '15': 0.02045,
#      '16': 0.025889999999999996,
#      '17': 0.01093,
#      '18': 0.01873,
#      '19': 0.003187,
#      '2': 86.24,
#      '20': 14.97,
#      '21': 25.41,
#      '22': 97.66,
#      '23': 686.5,
#      '24': 0.1313,
#      '25': 0.2119,
#      '26': 0.2267,
#      '27': 0.09992999999999999,
#      '28': 0.2822,
#      '29': 0.08004,
#      '3': 551.1,
#      '4': 0.09587000000000001,
#      '5': 0.09262999999999999,
#      '6': 0.06154,
#      '7': 0.0335,
#      '8': 0.1792,
#      '9': 0.06154},
#     'categorical_columns': [],
#     'categorical_columns_encoding_mapping': {},
#     'categorical_counts': {},
#     'class_labels': ['M', 'B'],
#     'd_bins': {'0': [11.7, 13.37, 15.78],
#      '1': [16.17, 18.84, 21.8],
#      '10': [0.2324, 0.3242, 0.4789],
#      '11': [0.8339, 1.1079999999999999, 1.474],
#      '12': [1.6059999999999999, 2.287, 3.3569999999999998],
#      '13': [17.85, 24.53, 45.19],
#      '14': [0.005169, 0.006379999999999999, 0.008145999999999999],
#      '15': [0.013080000000000001, 0.02045, 0.03245],
#      '16': [0.015090000000000001, 0.025889999999999996, 0.04205],
#      '17': [0.007638, 0.01093, 0.014709999999999999],
#      '18': [0.01516, 0.01873, 0.02348],
#      '19': [0.002248, 0.003187, 0.0045579999999999996],
#      '2': [75.17, 86.24, 104.1],
#      '20': [13.01, 14.97, 18.79],
#      '21': [21.08, 25.41, 29.72],
#      '22': [84.11, 97.66, 125.4],
#      '23': [515.3, 686.5, 1084.0],
#      '24': [0.1166, 0.1313, 0.146],
#      '25': [0.1472, 0.2119, 0.3391],
#      '26': [0.1145, 0.2267, 0.3829],
#      '27': [0.06493, 0.09992999999999999, 0.1614],
#      '28': [0.2504, 0.2822, 0.3179],
#      '29': [0.07146, 0.08004, 0.09208],
#      '3': [420.3, 551.1, 782.7],
#      '4': [0.08637, 0.09587000000000001, 0.1053],
#      '5': [0.06492, 0.09262999999999999, 0.1304],
#      '6': [0.029560000000000003, 0.06154, 0.1307],
#      '7': [0.020309999999999998, 0.0335, 0.07400000000000001],
#      '8': [0.1619, 0.1792, 0.1957],
#      '9': [0.0577, 0.06154, 0.06612]},
#     'd_maxs': {'0': [11.7, 13.37, 15.78, 28.11],
#      '1': [16.17, 18.84, 21.8, 39.28],
#      '10': [0.2324, 0.3242, 0.4789, 2.873],
#      '11': [0.8339, 1.1079999999999999, 1.474, 4.885],
#      '12': [1.6059999999999999, 2.287, 3.3569999999999998, 21.98],
#      '13': [17.85, 24.53, 45.19, 542.2],
#      '14': [0.005169, 0.006379999999999999, 0.008145999999999999, 0.03113],
#      '15': [0.013080000000000001, 0.02045, 0.03245, 0.1354],
#       0.006076814593402667]},
#     'feature_columns': ['radius_mean',
#      'texture_mean',
#      'perimeter_mean',
#      'area_mean',
#      'smoothness_mean',
#      'compactness_mean',
#      'concavity_mean',
#      'concave points_mean',
#      'symmetry_mean',
#      'fractal_dimension_mean',
#      'radius_se',
#      'texture_se',
#      'perimeter_se',
#      'area_se',
#      'smoothness_se',
#      'compactness_se',
#      'concavity_se',
#      'concave points_se',
#      'symmetry_se',
#      'fractal_dimension_se',
#      'radius_worst',
#      'texture_worst',
#      'perimeter_worst',
#      'area_worst',
#      'smoothness_worst',
#      'compactness_worst',
#      'concavity_worst',
#      'concave points_worst',
#      'symmetry_worst',
#      'fractal_dimension_worst'],
#     'feature_frequencies': {'0': [142, 143, 142, 142],
#      '1': [143, 142, 142, 142],
#      '10': [142, 142, 142, 143],
#      '11': [142, 143, 142, 142],
#      '12': [142, 142, 142, 143],
#      '13': [142, 142, 142, 143],
#      '14': [142, 142, 142, 143],
#      '15': [142, 143, 142, 142],
#      '16': [142, 142, 142, 143],
#      '17': [142, 142, 142, 143],
#      '18': [142, 143, 142, 142],
#      '19': [142, 142, 143, 142],
#      '2': [142, 142, 142, 143],
#      '20': [142, 143, 141, 143],
#      '21': [143, 142, 142, 142],
#      '22': [142, 142, 142, 143],
#      '23': [142, 142, 142, 143],
#      '24': [142, 141, 142, 144],
#      '25': [142, 142, 142, 143],
#      '26': [142, 142, 142, 143],
#      '27': [142, 142, 142, 143],
#      '28': [142, 142, 143, 142],
#      '29': [142, 142, 142, 143],
#      '3': [142, 144, 141, 142],
#      '4': [142, 143, 142, 142],
#      '5': [142, 142, 142, 143],
#      '6': [142, 142, 142, 143],
#      '7': [142, 142, 142, 143],
#      '8': [141, 143, 143, 142],
#      '9': [142, 143, 142, 142]},
#     'feature_values': {'0': [3, 0, 1, 2],
#      '1': [0, 1, 2, 3],
#      '10': [3, 2, 1, 0],
#      '11': [1, 0, 2, 3],
#      '12': [3, 1, 2, 0],
#      '13': [3, 2, 1, 0],
#      '14': [2, 1, 3, 0],
#      '15': [3, 0, 2, 1],
#      '16': [3, 1, 2, 0],
#      '17': [3, 2, 1, 0],
#      '18': [3, 0, 2, 1],
#      '19': [3, 2, 0, 1],
#      '2': [3, 1, 2, 0],
#      '20': [3, 1, 2, 0],
#      '21': [0, 1, 2, 3],
#      '22': [3, 2, 1, 0],
#      '23': [3, 1, 2, 0],
#      '24': [3, 1, 2, 0],
#      '25': [3, 1, 2, 0],
#      '26': [3, 2, 1, 0],
#      '27': [3, 2, 1, 0],
#      '28': [3, 1, 0, 2],
#      '29': [3, 2, 1, 0],
#      '3': [3, 0, 1, 2],
#      '4': [3, 0, 2, 1],
#      '5': [3, 1, 2, 0],
#      '6': [3, 2, 1, 0],
#      '7': [3, 2, 1, 0],
#      '8': [3, 2, 0, 1],
#      '9': [3, 0, 1, 2]},
#     'maxs': {'0': 28.11,
#      '1': 39.28,
#      '10': 2.873,
#      '11': 4.885,
#      '12': 21.98,
#      '13': 542.2,
#      '14': 0.03113,
#      '15': 0.1354,
#      '16': 0.396,
#      '17': 0.05279,
#      '18': 0.07895,
#      '19': 0.02984,
#      '2': 188.5,
#      '20': 36.04,
#      '21': 49.54,
#      '22': 251.2,
#      '23': 4254.0,
#      '24': 0.2226,
#      '25': 1.058,
#      '26': 1.252,
#      '27': 0.29100000000000004,
#      '28': 0.6638,
#      '29': 0.2075,
#      '3': 2501.0,
#      '4': 0.1634,
#      '5': 0.3454,
#      '6': 0.4268,
#      '7': 0.2012,
#      '8': 0.304,
#      '9': 0.09744},
#     'mins': {'0': 6.981,
#      '1': 9.71,
#      '10': 0.1115,
#      '11': 0.3602,
#      '12': 0.757,
#      '13': 6.8020000000000005,
#      '14': 0.001713,
#      '15': 0.002252,
#      '16': 0.0,
#      '17': 0.0,
#      '18': 0.007882,
#      '19': 0.0008948000000000001,
#      '2': 43.79,
#      '20': 7.93,
#      '21': 12.02,
#      '22': 50.41,
#      '23': 185.2,
#      '24': 0.07117000000000001,
#      '25': 0.02729,
#      '26': 0.0,
#      '27': 0.0,
#      '28': 0.1565,
#      '29': 0.05504,
#      '3': 143.5,
#      '4': 0.052629999999999996,
#      '5': 0.01938,
#      '6': 0.0,
#      '7': 0.0,
#      '8': 0.106,
#      '9': 0.049960000000000004},
#     'stds': {'0': 3.520950760711062,
#      '1': 4.297254637090422,
#      '10': 0.27706894152536526,
#      '11': 0.551163426903576,
#      '12': 2.0200770991455244,
#      '13': 45.45101341563996,
#      '14': 0.0029998783671144756,
#      '15': 0.017892435868281962,
#      '16': 0.03015952312197047,
#      '17': 0.006164860746471701,
#      '18': 0.008259104387588135,
#      '19': 0.0026437447504047374,
#      '2': 24.27761929305318,
#      '20': 4.828992576060772,
#      '21': 6.1408543185890005,
#      '22': 33.57300156682593,
#      '23': 568.8564589532671,
#      '24': 0.022812356935544644,
#      '25': 0.15719817109455372,
#      '26': 0.20844087461170602,
#      '27': 0.06567455451119314,
#      '28': 0.06181307854455481,
#      '29': 0.01804538930859499,
#      '3': 351.60475406323,
#      '4': 0.014051764066591203,
#      '5': 0.05276632912535515,
#      '6': 0.07964972534603185,
#      '7': 0.03876873246147476,
#      '8': 0.02739018086426853,
#      '9': 0.007054155881537345}}},
#   'fairness_monitoring': {'class_label': 'predicted_label',
#    'distributions': [{'attribute': 'radius_mean',
#      'class_labels': [{'counts': [{'class_value': 'B', 'count': 1}],
#        'label': '[6.8, 7.2]'},
#       {'counts': [{'class_value': 'B', 'count': 3}], 'label': '[7.6, 8.0]'},
#       {'counts': [{'class_value': 'B', 'count': 2}], 'label': '[8.0, 8.4]'},
#       {'counts': [{'class_value': 'B', 'count': 7}], 'label': '[8.4, 8.8]'},
#       {'counts': [{'class_value': 'B', 'count': 7}], 'label': '[8.8, 9.2]'},
#       {'counts': [{'class_value': 'B', 'count': 10}], 'label': '[9.2, 9.6]'},
#       {'counts': [{'class_value': 'B', 'count': 17}], 'label': '[9.6, 10.0]'},
#       {'counts': [{'class_value': 'B', 'count': 13}], 'label': '[10.0, 10.4]'},
#       {'counts': [{'class_value': 'B', 'count': 16}], 'label': '[10.4, 10.8]'},
#       {'counts': [{'class_value': 'B', 'count': 20},
#         {'class_value': 'M', 'count': 2}],
#        'label': '[10.8, 11.2]'},
#       {'counts': [{'class_value': 'B', 'count': 35},
#         {'class_value': 'M', 'count': 1}],
#        'label': '[11.2, 11.6]'},
#       {'counts': [{'class_value': 'B', 'count': 34},
#         {'class_value': 'M', 'count': 3}],
#        'label': '[11.6, 12.0]'},
#       {'counts': [{'class_value': 'B', 'count': 33},
#         {'class_value': 'M', 'count': 1}],
#        'label': '[12.0, 12.4]'},
#       {'counts': [{'class_value': 'B', 'count': 27},
#         {'class_value': 'M', 'count': 4}],
#        'label': '[12.4, 12.8]'},
#       {'counts': [{'class_value': 'B', 'count': 34},
#         {'class_value': 'M', 'count': 5}],
#        'label': '[12.8, 13.2]'},
#       {'counts': [{'class_value': 'B', 'count': 23},
#         {'class_value': 'M', 'count': 5}],
#        'label': '[13.2, 13.6]'},
#       {'counts': [{'class_value': 'B', 'count': 23},
#         {'class_value': 'M', 'count': 11}],
#        'label': '[13.6, 14.0]'},
#       {'counts': [{'class_value': 'B', 'count': 13},
#         {'class_value': 'M', 'count': 5}],
#        'label': '[14.0, 14.4]'},
#       {'counts': [{'class_value': 'B', 'count': 17},
#         {'class_value': 'M', 'count': 9}],
#        'label': '[14.4, 14.8]'},
#       {'counts': [{'class_value': 'B', 'count': 10},
#         {'class_value': 'M', 'count': 5}],
#        'label': '[14.8, 15.0]'},
#       {'counts': [{'class_value': 'B', 'count': 3},
#         {'class_value': 'M', 'count': 6}],
#        'label': '[15.0, 15.2]'},
#       {'counts': [{'class_value': 'B', 'count': 1},
#         {'class_value': 'M', 'count': 12}],
#        'label': '[15.2, 15.6]'},
#       {'counts': [{'class_value': 'B', 'count': 2},
#         {'class_value': 'M', 'count': 8}],
#        'label': '[15.6, 16.0]'},
#       {'counts': [{'class_value': 'B', 'count': 3},
#         {'class_value': 'M', 'count': 12}],
#        'label': '[16.0, 16.4]'},
#       {'counts': [{'class_value': 'B', 'count': 1},
#         {'class_value': 'M', 'count': 6}],
#        'label': '[16.4, 16.8]'},
#       {'counts': [{'class_value': 'B', 'count': 1},
#         {'class_value': 'M', 'count': 8}],
#        'label': '[16.8, 17.2]'},
#       {'counts': [{'class_value': 'M', 'count': 10}], 'label': '[17.2, 17.6]'},
#       {'counts': [{'class_value': 'B', 'count': 1},
#         {'class_value': 'M', 'count': 7}],
#        'label': '[17.6, 18.0]'},
#       {'counts': [{'class_value': 'M', 'count': 9}],
#        'label': '[18.0, 18.39999]'},
#       {'counts': [{'class_value': 'M', 'count': 8}],
#        'label': '[18.39999, 18.79999]'},
#       {'counts': [{'class_value': 'M', 'count': 4}],
#        'label': '[18.79999, 19.0]'},
#       {'counts': [{'class_value': 'M', 'count': 7}],
#        'label': '[19.0, 19.19999]'},
#       {'counts': [{'class_value': 'M', 'count': 12}],
#        'label': '[19.19999, 19.59999]'},
#       {'counts': [{'class_value': 'M', 'count': 7}],
#        'label': '[19.59999, 19.99999]'},
#       {'counts': [{'class_value': 'M', 'count': 10}],
#        'label': '[20.0, 20.39999]'},
#       {'counts': [{'class_value': 'M', 'count': 35}],
#        'label': '[20.39999, 28.11]'}],
#      'max': 28.11,
#      'min': 6.981},
#     {'attribute': 'diagnosis',
#      'distinct_values': ['B', 'M'],
#      'is_class_label': True}],
#    'favourable_class': ['M'],
#    'features': [{'feature': 'radius_mean',
#      'majority': [[0.0, 10.0], [19.0, 20.0]],
#      'minority': [[15.0, 16.0]],
#      'threshold': 0.8,
#      'type': 'float'}],
#    'min_records': 5,
#    'perform_debias': True,
#    'run_status': 'INITIATED',
#    'training_data_class_label': None,
#    'unfavourable_class': ['B']},
#   'payload_logging': {'dynamic_schema_update': True,
#    'output_data_schema': {'fields': [{'metadata': {'modeling_role': 'feature'},
#       'name': 'radius_mean',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'feature'},
#       'name': 'texture_mean',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'feature'},
#       'name': 'perimeter_mean',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'feature'},
#       'name': 'area_mean',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'feature'},
#       'name': 'smoothness_mean',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'feature'},
#       'name': 'compactness_mean',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'feature'},
#       'name': 'concavity_mean',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'feature'},
#       'name': 'concave points_mean',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'feature'},
#       'name': 'symmetry_mean',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'feature'},
#       'name': 'fractal_dimension_mean',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'feature'},
#       'name': 'radius_se',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'feature'},
#       'name': 'texture_se',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'feature'},
#       'name': 'perimeter_se',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'feature'},
#       'name': 'area_se',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'feature'},
#       'name': 'smoothness_se',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'feature'},
#       'name': 'compactness_se',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'feature'},
#       'name': 'concavity_se',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'feature'},
#       'name': 'concave points_se',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'feature'},
#       'name': 'symmetry_se',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'feature'},
#       'name': 'fractal_dimension_se',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'feature'},
#       'name': 'radius_worst',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'feature'},
#       'name': 'texture_worst',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'feature'},
#       'name': 'perimeter_worst',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'feature'},
#       'name': 'area_worst',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'feature'},
#       'name': 'smoothness_worst',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'feature'},
#       'name': 'compactness_worst',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'feature'},
#       'name': 'concavity_worst',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'feature'},
#       'name': 'concave points_worst',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'feature'},
#       'name': 'symmetry_worst',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'feature'},
#       'name': 'fractal_dimension_worst',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'prediction'},
#       'name': 'predicted_label',
#       'nullable': True,
#       'type': 'double'},
#      {'metadata': {'modeling_role': 'probability'},
#       'name': 'score',
#       'nullable': True,
#       'type': {'containsNull': True,
#        'elementType': 'double',
#        'type': 'array'}}],
#     'type': 'struct'}},
#   'performance_monitoring': {},
#   'quality_monitoring': {'evaluation_definition': {'method': 'multiclass',
#     'threshold': 0.8},
#    'min_feedback_data_size': 5,
#    'scheduleId': '63c7f400-aa29-4539-91ad-8a4b9d2b9a51'}},
#  'deployments': [{'created_at': '2018-10-10T14:39:21.421Z',
#    'deployment_id': '37a83f399e6dc3b9d08d7d01fe690665',
#    'deployment_rn': 'arn:aws:sagemaker:us-east-1:014862798213:endpoint/demo-multi-classification-endpoint-201810101439',
#    'deployment_type': 'online',
#    'name': 'DEMO-multi-classification-endpoint-201810101439',
#    'scoring_endpoint': {'request_headers': {'Content-Type': 'application/json'},
#     'url': 'DEMO-multi-classification-endpoint-201810101439'},
#    'url': 'DEMO-multi-classification-endpoint-201810101439'}],
#  'export_info': {'api_version': 'v1',
#   'origin': '/v1/data_marts/b73545e6-0a6e-466c-8cd0-c47c044c5702/service_bindings/bf44cc7f-990d-4942-bfc6-cbcf71a1b78c/subscriptions/0530ab0cd4f4dd5486b19c08df8b6914',
#   'timestamp': '2019-02-11T11:41:01.613Z'}}

# %% [markdown]
# ### 3.2 Add subscriptions from configuration file

# %%
subscription = client.data_mart.subscriptions.import_configuration(binding_uid=binding_uid, configuration_data=subscription_configuration)

# %% [markdown]
# #### List subscriptions

# %%
client.data_mart.subscriptions.list()
# Out:
# <HTML>
#         <body>
#             <h3>Subscriptions</h3>
#             <table style='border: 1px solid #dddddd; font-family: Courier'>
#                 <th style='border: 1px solid #dddddd'>uid</th><th style='border: 1px solid #dddddd'>name</th><th style='border: 1px solid #dddddd'>type</th><th style='border: 1px solid #dddddd'>binding_uid</th><th style='border: 1px solid #dddddd'>created</th>
#                 <tr><td style='border: 1px solid #dddddd'>0530ab0cd4f4dd5486b19c08df8b6914</td><td style='border: 1px solid #dddddd'>DEMO-multi-classification-2018-10-10-14-26-26</td><td style='border: 1px solid #dddddd'>model</td><td style='border: 1px solid #dddddd'>d47e97b7-07d7-4874-b604-e47ff1a0cd26</td><td style='border: 1px solid #dddddd'>2019-02-14T12:50:55.426Z</td></tr><tr><td style='border: 1px solid #dddddd'>0f1d511c-b121-44d1-b3f7-c3ad258211f5</td><td style='border: 1px solid #dddddd'>AIOS Spark German Risk Model - Final</td><td style='border: 1px solid #dddddd'>model</td><td style='border: 1px solid #dddddd'>a73bf76d-a663-448a-b771-4f651f73d54e</td><td style='border: 1px solid #dddddd'>2019-02-13T10:36:38.050Z</td></tr><tr><td style='border: 1px solid #dddddd'>085460ef94636166aea5800e9ea26168</td><td style='border: 1px solid #dddddd'>GermanCreditRisk.2019.1.9.10.41.58.611</td><td style='border: 1px solid #dddddd'>model</td><td style='border: 1px solid #dddddd'>91d749e3-8551-45da-84fc-385e7ed2ba26</td><td style='border: 1px solid #dddddd'>2019-02-07T12:46:42.998Z</td></tr>
#             </table>
#         </body>
#         </HTML>

# %% [markdown]
# ### 3.3 Export subscription configuration

# %%
exported_configuration = client.data_mart.subscriptions.export_configuration(binding_uid=binding_uid, subscription_uid=subscription.uid)

# %%
exported_configuration
# Out:
# {'asset': {'asset_id': '0530ab0cd4f4dd5486b19c08df8b6914',
#   'asset_type': 'model',
#   'created_at': '2018-10-10T14:31:44.348Z',
#   'name': 'DEMO-multi-classification-2018-10-10-14-26-26',
#   'url': 's3://sagemaker-us-east-1-014862798213/sagemaker/DEMO-breast-cancer-prediction/DEMO-multi-classification-2018-10-10-14-26-26/output/model.tar.gz'},
#  'asset_properties': {'categorical_fields': [],
#   'feature_fields': ['radius_mean',
#    'texture_mean',
#    'perimeter_mean',
#    'area_mean',
#    'smoothness_mean',
#    'compactness_mean',
#    'concavity_mean',
#    'concave points_mean',
#    'symmetry_mean',
#    'fractal_dimension_mean',
#    'radius_se',
#    'texture_se',
#    'perimeter_se',
#    'area_se',
#    'smoothness_se',
#    'compactness_se',
#    'concavity_se',
#    'concave points_se',
#    'symmetry_se',
#    'fractal_dimension_se',
#    'radius_worst',
#    'texture_worst',
#    'perimeter_worst',
#    'area_worst',
#    'smoothness_worst',
#    'compactness_worst',
#    'concavity_worst',
#    'concave points_worst',
#    'symmetry_worst',
#    'fractal_dimension_worst'],
#   'input_data_schema': {'fields': [{'metadata': {'modeling_role': 'feature'},
#      'name': 'radius_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'texture_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'perimeter_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'area_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'smoothness_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'compactness_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concavity_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concave points_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'symmetry_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'fractal_dimension_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'radius_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'texture_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'perimeter_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'area_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'smoothness_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'compactness_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concavity_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concave points_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'symmetry_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'fractal_dimension_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'radius_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'texture_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'perimeter_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'area_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'smoothness_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'compactness_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concavity_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concave points_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'symmetry_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'fractal_dimension_worst',
#      'nullable': True,
#      'type': 'double'}],
#    'type': 'struct'},
#   'input_data_type': 'structured',
#   'label_column': 'diagnosis',
#   'output_data_schema': {'fields': [{'metadata': {'modeling_role': 'feature'},
#      'name': 'radius_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'texture_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'perimeter_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'area_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'smoothness_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'compactness_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concavity_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concave points_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'symmetry_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'fractal_dimension_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'radius_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'texture_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'perimeter_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'area_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'smoothness_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'compactness_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concavity_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concave points_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'symmetry_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'fractal_dimension_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'radius_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'texture_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'perimeter_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'area_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'smoothness_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'compactness_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concavity_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concave points_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'symmetry_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'fractal_dimension_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'prediction'},
#      'name': 'predicted_label',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'probability'},
#      'name': 'score',
#      'nullable': True,
#      'type': {'containsNull': True,
#       'elementType': 'double',
#       'type': 'array'}}],
#    'type': 'struct'},
#   'prediction_field': 'predicted_label',
#   'prediction_probability_field': 'score',
#   'problem_type': 'multiclass',
#   'training_data_schema': {'fields': [{'metadata': {'modeling_role': 'feature'},
#      'name': 'radius_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'texture_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'perimeter_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'area_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'smoothness_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'compactness_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concavity_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concave points_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'symmetry_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'fractal_dimension_mean',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'radius_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'texture_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'perimeter_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'area_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'smoothness_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'compactness_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concavity_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concave points_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'symmetry_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'fractal_dimension_se',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'radius_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'texture_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'perimeter_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'area_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'smoothness_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'compactness_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concavity_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'concave points_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'symmetry_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'feature'},
#      'name': 'fractal_dimension_worst',
#      'nullable': True,
#      'type': 'double'},
#     {'metadata': {'modeling_role': 'target'},
#      'name': 'diagnosis',
#      'nullable': True,
#      'type': 'double'}],
#    'type': 'struct'}},
#  'configurations': {'explainability': {'training_statistics': {'base_values': {'0': 13.37,
#      '1': 18.84,
#      '10': 0.3242,
#      '11': 1.1079999999999999,
#      '12': 2.287,
#      '13': 24.53,
#      '14': 0.006379999999999999,
#      '15': 0.02045,
#      '16': 0.025889999999999996,
#      '17': 0.01093,
#      '18': 0.01873,
#      '19': 0.003187,
#      '2': 86.24,
#      '20': 14.97,
#      '21': 25.41,
#      '22': 97.66,
#      '23': 686.5,
#      '24': 0.1313,
#      '25': 0.2119,
#      '26': 0.2267,
#      '27': 0.09992999999999999,
#      '28': 0.2822,
#      '29': 0.08004,
#      '3': 551.1,
#      '4': 0.09587000000000001,
#      '5': 0.09262999999999999,
#      '6': 0.06154,
#      '7': 0.0335,
#      '8': 0.1792,
#      '9': 0.06154},
#     'categorical_columns': [],
#     'categorical_columns_encoding_mapping': {},
#     'categorical_counts': {},
#     'class_labels': ['M', 'B'],
#     'd_bins': {'0': [11.7, 13.37, 15.78],
#      '1': [16.17, 18.84, 21.8],
#      '10': [0.2324, 0.3242, 0.4789],
#      '11': [0.8339, 1.1079999999999999, 1.474],
#      '12': [1.6059999999999999, 2.287, 3.3569999999999998],
#      '13': [17.85, 24.53, 45.19],
#      '14': [0.005169, 0.006379999999999999, 0.008145999999999999],
#      '15': [0.013080000000000001, 0.02045, 0.03245],
#      '16': [0.015090000000000001, 0.025889999999999996, 0.04205],
#      '17': [0.007638, 0.01093, 0.014709999999999999],
#      '18': [0.01516, 0.01873, 0.02348],
#      '19': [0.002248, 0.003187, 0.0045579999999999996],
#      '2': [75.17, 86.24, 104.1],
#      '20': [13.01, 14.97, 18.79],
#      '21': [21.08, 25.41, 29.72],
#      '22': [84.11, 97.66, 125.4],
#      '23': [515.3, 686.5, 1084.0],
#      '24': [0.1166, 0.1313, 0.146],
#      '25': [0.1472, 0.2119, 0.3391],
#      '26': [0.1145, 0.2267, 0.3829],
#      '27': [0.06493, 0.09992999999999999, 0.1614],
#      '28': [0.2504, 0.2822, 0.3179],
#      '29': [0.07146, 0.08004, 0.09208],
#      '3': [420.3, 551.1, 782.7],
#      '4': [0.08637, 0.09587000000000001, 0.1053],
#      '5': [0.06492, 0.09262999999999999, 0.1304],
#      '6': [0.029560000000000003, 0.06154, 0.1307],
#      '7': [0.020309999999999998, 0.0335, 0.07400000000000001],
#      '8': [0.1619, 0.1792, 0.1957],
#      '9': [0.0577, 0.06154, 0.06612]},
#     'd_maxs': {'0': [11.7, 13.37, 15.78, 28.11],
#      '1': [16.17, 18.84, 21.8, 39.28],
#      '10': [0.2324, 0.3242, 0.4789, 2.873],
#      '11': [0.8339, 1.1079999999999999, 1.474, 4.885],
#      '12': [1.6059999999999999, 2.287, 3.3569999999999998, 21.98],
#      '13': [17.85, 24.53, 45.19, 542.2],
#      '14': [0.005169, 0.006379999999999999, 0.008145999999999999, 0.03113],
#      '15': [0.013080000000000001, 0.02045, 0.03245, 0.1354],
#      '16': [0.015090000000000001, 0.025889999999999996, 0.04205, 0.396],
#      '17': [0.007638, 0.01093, 0.014709999999999999, 0.05279],
#      '18': [0.01516, 0.01873, 0.02348, 0.07895],
#      '19': [0.002248, 0.003187, 0.0045579999999999996, 0.02984],
#      '2': [75.17, 86.24, 104.1, 188.5],
#      '20': [13.01, 14.97, 18.79, 36.04],
#      '21': [21.08, 25.41, 29.72, 49.54],
#      '22': [84.11, 97.66, 125.4, 251.2],
#      '23': [515.3, 686.5, 1084.0, 4254.0],
#      '24': [0.1166, 0.1313, 0.146, 0.2226],
#      '25': [0.1472, 0.2119, 0.3391, 1.058],
#      '26': [0.1145, 0.2267, 0.3829, 1.252],
#      '27': [0.06493, 0.09992999999999999, 0.1614, 0.29100000000000004],
#      '28': [0.2504, 0.2822, 0.3179, 0.6638],
#      '29': [0.07146, 0.08004, 0.09208, 0.2075],
#      '16': [0.004727089225244372,
#       0.0028724001566819003,
#       0.00464113072424251,
#       0.04093554367121596],
#      '17': [0.0021048576615265552,
#       0.0008969896239787771,
#       0.0010716003442356986,
#       0.0056519803224296915],
#      '18': [0.0014668705442205587,
#       0.0010999776657215558,
#       0.0013377143115861502,
#       0.008818772425438251],
#      '19': [0.0003111337814836514,
#       0.00025789689907731084,
#       0.0003821624367410607,
#       0.0034972208998836187],
#      '2': [6.913090419647279,
#       3.2129348772973296,
#       5.176955838303058,
#       16.878971389394426],
#      '20': [1.1373619020190397,
#       0.5768723775237646,
#       1.025045297191829,
#       3.3780537757870026],
#      '21': [1.928550488878979,
#       1.2592236408865967,
#       1.2370962960137482,
#       3.6630263548124042],
#      '22': [7.625401387806163,
#       3.9989459314755855,
#       7.813691170538253,
#       24.20596431853211],
#      '23': [78.0638026988224,
#       48.850828856481755,
#       104.10845046605424,
#       530.058971849527],
#      '24': [0.008857724713131938,
#       0.004122000712847578,
#       0.003947398642152424,
#       0.014603598157490984],
#      '25': [0.02872895764932115,
#       0.018763338544010324,
#       0.035059486652705835,
#       0.1376755510915267],
#      '26': [0.035752032922873614,
#       0.030751114001269113,
#       0.04604944238584604,
#       0.16169566001818642],
#      '27': [0.019330398865220297,
#       0.009765958960120232,
#       0.019127303630762475,
#       0.03170023295701572],
#      '28': [0.021309614929193244,
#       0.009245797293482938,
#       0.010535092768428128,
#       0.05902489974252673],
#      '29': [0.003962205484062444,
#       0.002362539226456686,
#       0.0036359168267047545,
#       0.016691032344900138],
#      '3': [65.28924070454488,
#       36.7571488222153,
#       63.41500160519485,
#       310.4752674914228],
#      '4': [0.005606417566252128,
#       0.002799066175620938,
#       0.002651882204924726,
#       0.00888699887126732],
#      '5': [0.009817736295789086,
#       0.007546305457539079,
#       0.010587734488378549,
#       0.04268980264085062],
#      '6': [0.009353002616278534,
#       0.009042096356150537,
#       0.01880711061539462,
#       0.06484417454661551],
#      '7': [0.0062072253370401296,
#       0.0037213483423964118,
#       0.011198891575116818,
#       0.027864776346188672],
#      '8': [0.010431219444556892,
#       0.0049421403901787515,
#       0.005030913395353463,
#       0.02025762625185471],
#      '9': [0.0018125047780373558,
#       0.0010448988062220837,
#       0.001340663944681915,
#       0.006076814593402667]},
#     'feature_columns': ['radius_mean',
#      'texture_mean',
#      'perimeter_mean',
#      'area_mean',
#      'smoothness_mean',
#      'compactness_mean',
#      'concavity_mean',
#      'concave points_mean',
#      'symmetry_mean',
#      'fractal_dimension_mean',
#      'radius_se',
#      'texture_se',
#      'perimeter_se',
#      'area_se',
#      'smoothness_se',
#      'compactness_se',
#      'concavity_se',
#      'concave points_se',
#      'symmetry_se',
#      'fractal_dimension_se',
#      'radius_worst',
#      'texture_worst',
#      'perimeter_worst',
#      'area_worst',
#      'smoothness_worst',
#      'compactness_worst',
#      'concavity_worst',
#      'concave points_worst',
#      'symmetry_worst',
#      'fractal_dimension_worst'],
#     'feature_frequencies': {'0': [142, 143, 142, 142],
#      '1': [143, 142, 142, 142],
#      '10': [142, 142, 142, 143],
#      '11': [142, 143, 142, 142],
#      '12': [142, 142, 142, 143],
#      '13': [142, 142, 142, 143],
#      '14': [142, 142, 142, 143],
#      '15': [142, 143, 142, 142],
#      '16': [142, 142, 142, 143],
#      '17': [142, 142, 142, 143],
#      '18': [142, 143, 142, 142],
#      '19': [142, 142, 143, 142],
#      '2': [142, 142, 142, 143],
#      '20': [142, 143, 141, 143],
#      '21': [143, 142, 142, 142],
#      '22': [142, 142, 142, 143],
#      '23': [142, 142, 142, 143],
#      '24': [142, 141, 142, 144],
#      '25': [142, 142, 142, 143],
#      '26': [142, 142, 142, 143],
#      '27': [142, 142, 142, 143],
#      '28': [142, 142, 143, 142],
#      '29': [142, 142, 142, 143],
#      '3': [142, 144, 141, 142],
#      '4': [142, 143, 142, 142],
#      '5': [142, 142, 142, 143],
#      '6': [142, 142, 142, 143],
#      '7': [142, 142, 142, 143],
#      '8': [141, 143, 143, 142],
#      '9': [142, 143, 142, 142]},
#     'feature_values': {'0': [3, 0, 1, 2],
#      '1': [0, 1, 2, 3],
#      '10': [3, 2, 1, 0],
#      '11': [1, 0, 2, 3],
#      '12': [3, 1, 2, 0],
#      '13': [3, 2, 1, 0],
#      '14': [2, 1, 3, 0],
#      '15': [3, 0, 2, 1],
#      '16': [3, 1, 2, 0],
#      '17': [3, 2, 1, 0],
#      '18': [3, 0, 2, 1],
#      '19': [3, 2, 0, 1],
#      '2': [3, 1, 2, 0],
#      '20': [3, 1, 2, 0],
#      '21': [0, 1, 2, 3],
#      '22': [3, 2, 1, 0],
#      '23': [3, 1, 2, 0],
#      '24': [3, 1, 2, 0],
#      '25': [3, 1, 2, 0],
#      '26': [3, 2, 1, 0],
#      '27': [3, 2, 1, 0],
#      '28': [3, 1, 0, 2],
#      '29': [3, 2, 1, 0],
#      '3': [3, 0, 1, 2],
#      '4': [3, 0, 2, 1],
#      '5': [3, 1, 2, 0],
#      '6': [3, 2, 1, 0],
#      '7': [3, 2, 1, 0],
#      '8': [3, 2, 0, 1],
#      '9': [3, 0, 1, 2]},
#     'maxs': {'0': 28.11,
#      '1': 39.28,
#      '10': 2.873,
#      '11': 4.885,
#      '12': 21.98,
#      '13': 542.2,
#      '14': 0.03113,
#      '15': 0.1354,
#      '16': 0.396,
#      '17': 0.05279,
#      '18': 0.07895,
#      '19': 0.02984,
#      '2': 188.5,
#      '20': 36.04,
#      '21': 49.54,
#      '22': 251.2,
#      '23': 4254.0,
#      '24': 0.2226,
#      '25': 1.058,
#      '26': 1.252,
#      '27': 0.29100000000000004,
#      '28': 0.6638,
#      '29': 0.2075,
#      '3': 2501.0,
#      '4': 0.1634,
#      '5': 0.3454,
#      '6': 0.4268,
#      '7': 0.2012,
#      '8': 0.304,
#      '9': 0.09744},
#     'mins': {'0': 6.981,
#      '1': 9.71,
#      '10': 0.1115,
#      '11': 0.3602,
#      '12': 0.757,
#      '13': 6.8020000000000005,
#      '14': 0.001713,
#      '15': 0.002252,
#      '16': 0.0,
#      '17': 0.0,
#      '18': 0.007882,
#      '19': 0.0008948000000000001,
#      '2': 43.79,
#      '20': 7.93,
#      '21': 12.02,
#      '22': 50.41,
#      '23': 185.2,
#      '24': 0.07117000000000001,
#      '25': 0.02729,
#      '26': 0.0,
#      '27': 0.0,
#      '28': 0.1565,
#      '29': 0.05504,
#      '3': 143.5,
#      '4': 0.052629999999999996,
#      '5': 0.01938,
#      '6': 0.0,
#      '7': 0.0,
#      '8': 0.106,
#      '9': 0.049960000000000004},
#     'stds': {'0': 3.520950760711062,
#      '1': 4.297254637090422,
#      '10': 0.27706894152536526,
#      '11': 0.551163426903576,
#      '12': 2.0200770991455244,
#      '13': 45.45101341563996,
#      '14': 0.0029998783671144756,
#      '15': 0.017892435868281962,
#      '16': 0.03015952312197047,
#      '17': 0.006164860746471701,
#      '18': 0.008259104387588135,
#      '19': 0.0026437447504047374,
#      '2': 24.27761929305318,
#      '20': 4.828992576060772,
#      '21': 6.1408543185890005,
#      '22': 33.57300156682593,
#      '23': 568.8564589532671,
#      '24': 0.022812356935544644,
#      '25': 0.15719817109455372,
#      '26': 0.20844087461170602,
#      '27': 0.06567455451119314,
#      '28': 0.06181307854455481,
#      '29': 0.01804538930859499,
#      '3': 351.60475406323,
#      '4': 0.014051764066591203,
#      '5': 0.05276632912535515,
#      '6': 0.07964972534603185,
#      '7': 0.03876873246147476,
#      '8': 0.02739018086426853,
#      '9': 0.007054155881537345}}},
#   'fairness_monitoring': {'class_label': 'predicted_label',
#    'favourable_class': ['M'],
#    'features': [{'feature': 'radius_mean',
#      'majority': [[0.0, 10.0], [19.0, 20.0]],
#      'minority': [[15.0, 16.0]],
#      'threshold': 0.8}],
#    'last_processed_ts': '2019-02-14 12:51:57.766684',
#    'min_records': 5,
#    'next_evaluation_ts': '2019-02-14 13:51:57.766704',
#    'perform_debias': True,
#    'run_errors_count': 0,
#    'run_info_code': 'AIOSFM6003',
#    'run_info_message': 'There are no records in the payload logging table',
#    'run_status': 'FINISHED WITH ERRORS',
#    'unfavourable_class': ['B']},
#   'payload_logging': {'dynamic_schema_update': True},
#   'performance_monitoring': {},
#   'quality_monitoring': {'evaluation_definition': {'method': 'multiclass',
#     'threshold': 0.8},
#    'min_feedback_data_size': 5,
#    'scheduleId': '03f0b5a9-1463-4b37-8d8a-45bcd0c3ec0f'}},
#  'deployments': [{'created_at': '2018-10-10T14:39:21.421Z',
#    'deployment_id': '37a83f399e6dc3b9d08d7d01fe690665',
#    'deployment_rn': 'arn:aws:sagemaker:us-east-1:014862798213:endpoint/demo-multi-classification-endpoint-201810101439',
#    'deployment_type': 'online',
#    'name': 'DEMO-multi-classification-endpoint-201810101439',
#    'scoring_endpoint': {'request_headers': {'Content-Type': 'application/json'},
#     'url': 'DEMO-multi-classification-endpoint-201810101439'},
#    'url': 'DEMO-multi-classification-endpoint-201810101439'}],
#  'export_info': {'api_version': 'v1',
#   'origin': '/v1/data_marts/e3a38ab0-3884-454c-abc0-5e535eec36e6/service_bindings/d47e97b7-07d7-4874-b604-e47ff1a0cd26/subscriptions/0530ab0cd4f4dd5486b19c08df8b6914',
#   'timestamp': '2019-02-14T12:57:13.665Z'}}

# %% [markdown]
# <a id="scoring"></a>
# ## 4. Scoring and payload logging

# %% [markdown]
# ### 4.1 Score the cancer model and measure response time

# %%
import requests
import time
import json
import boto3

binding_details = client.data_mart.bindings.get_details(binding_uid=binding_uid)
subscription_details = subscription.get_details()

access_id = binding_details['entity']['credentials']['access_key_id']
access_key = binding_details['entity']['credentials']['secret_access_key']
region = binding_details['entity']['credentials']['region']
endpoint_name = subscription_details['entity']['deployments'][0]['name']
runtime = boto3.client('sagemaker-runtime', region_name=region, aws_access_key_id=access_id, aws_secret_access_key=access_key)

fields = ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean',
          'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se',
          'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se',
          'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst',
          'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst',
          'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst']
        
payload = "17.02,23.98,112.8,899.3,0.1197,0.1496,0.2417,0.1203,0.2248,0.06382,0.6009,1.398,3.999,67.78,0.008268,0.03082,0.05042,0.01112,0.02102,0.003854,20.88,32.09,136.1,1344,0.1634,0.3559,0.5588,0.1847,0.353,0.08482\n17.02,23.98,112.8,899.3,0.1197,0.1496,0.2417,0.1203,0.2248,0.06382,0.6009,1.398,3.999,67.78,0.008268,0.03082,0.05042,0.01112,0.02102,0.003854,20.88,32.09,136.1,1344,0.1634,0.3559,0.5588,0.1847,0.353,0.08482"

start_time = time.time()
response = runtime.invoke_endpoint(EndpointName=endpoint_name, ContentType='text/csv', Body=payload)
response_time = int((time.time() - start_time)*1000)
result = json.loads(response['Body'].read().decode())

print(json.dumps(result, indent=2))
# Out:
# {
#   "predictions": [
#     {
#       "score": [
#         5.532644564709699e-09,
#         1.0
#       ],
#       "predicted_label": 1.0
#     },
#     {
#       "score": [
#         5.532644564709699e-09,
#         1.0
#       ],
#       "predicted_label": 1.0
#     }
#   ]
# }

# %% [markdown]
# ### 4.2 Store the request and response in payload logging table

# %% [markdown]
# #### Transform the model's input and output to the format compatible with AI OpenScale standard.

# %%
values = []

for v in payload.split('\n'):
    values.append([float(s) for s in v.split(',')])

request_data = {'fields': fields, 'values': values}

response_data = {'fields': list(result['predictions'][0]),
            'values': [list(x.values()) for x in result['predictions']]}

# %% [markdown]
# #### Store the payload using Python SDK

# %% [markdown]
# **Hint:** You can embed payload logging code into your custom deployment so it is logged automatically each time you score the model.

# %%
records_list = [PayloadRecord(request=request_data, response=response_data, response_time=response_time), 
                PayloadRecord(request=request_data, response=response_data, response_time=response_time)]

for i in range(1, 10):
    records_list.append(PayloadRecord(request=request_data, response=response_data, response_time=response_time))

subscription.payload_logging.store(records=records_list)

# %% [markdown]
# <a id="feedback"></a>
# ## 5. Feedback logging & quality (accuracy) monitoring

# %% [markdown]
# ### Feedback records logging

# %% [markdown]
# The feedback records can be send to feedback table using below code.

# %%
feedback_records = []

fields = ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean',
          'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se',
          'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se',
          'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst',
          'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst',
          'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst', 'diagnosis']

for i in range(1, 10):
    feedback_records.append([17.02,23.98,112.8,899.3,0.1197,0.1496,0.2417,0.1203,0.2248,0.06382,0.6009,1.398,3.999,67.78,0.008268,0.03082,0.05042,0.01112,0.02102,0.003854,20.88,32.09,136.1,1344,0.1634,0.3559,0.5588,0.1847,0.353,0.08482, 1])

subscription.feedback_logging.store(feedback_data=feedback_records, fields=fields)

# %% [markdown]
# ### Run quality monitoring on demand

# %% [markdown]
# By default, quality monitoring is run on hourly schedule. You can also trigger it on demand using below code.

# %%
run_details = subscription.quality_monitoring.run(background_mode=False)
# Out:
# ================================================================================
#
#  Waiting for end of quality monitoring run d5c9f513-a6f8-4fec-9889-08b8ce9596f2
#
# ================================================================================
#
#
#
# initializing
# completed
#
# ---------------------------
#  Successfully finished run
# ---------------------------

# %% [markdown]
# ### Show the quality metrics

# %%
subscription.quality_monitoring.show_table()
# Out:
# <HTML>
#         <body>
#             <h3>QualityMetrics (binding_id=d47e97b7-07d7-4874-b604-e47ff1a0cd26, subscription_id=0530ab0cd4f4dd5486b19c08df8b6914)</h3>
#             <table style='border: 1px solid #dddddd; font-family: Courier'>
#                 <th style='border: 1px solid #dddddd'>ts</th><th style='border: 1px solid #dddddd'>quality</th><th style='border: 1px solid #dddddd'>quality_threshold</th><th style='border: 1px solid #dddddd'>binding_id</th><th style='border: 1px solid #dddddd'>subscription_id</th><th style='border: 1px solid #dddddd'>deployment_id</th><th style='border: 1px solid #dddddd'>process</th><th style='border: 1px solid #dddddd'>asset_revision</th>
#                 <tr><td style='border: 1px solid #dddddd'>2019-02-14 12:58:10.616000+00:00</td><td style='border: 1px solid #dddddd'>1.0</td><td style='border: 1px solid #dddddd'>0.8</td><td style='border: 1px solid #dddddd'>d47e97b7-07d7-4874-b604-e47ff1a0cd26</td><td style='border: 1px solid #dddddd'>0530ab0cd4f4dd5486b19c08df8b6914</td><td style='border: 1px solid #dddddd'>37a83f399e6dc3b9d08d7d01fe690665</td><td style='border: 1px solid #dddddd'>Accuracy_evaluation_d5c9f513-a6f8-4fec-9889-08b8ce9596f2</td><td style='border: 1px solid #dddddd'></td></tr>
#             </table>
#         </body>
#         </HTML>

# %% [markdown]
# Get all calculated metrics.

# %%
deployment_uid = subscription.get_deployment_uids()[0]

# %%
subscription.quality_monitoring.get_metrics(deployment_uid=deployment_uid)
# Out:
# {'end': '2019-02-14T12:58:26.874423Z',
#  'metrics': [{'process': 'Accuracy_evaluation_d5c9f513-a6f8-4fec-9889-08b8ce9596f2',
#    'timestamp': '2019-02-14T12:58:10.616Z',
#    'value': {'metrics': [{'name': 'weightedTruePositiveRate', 'value': 1.0},
#      {'name': 'accuracy', 'value': 1.0},
#      {'name': 'weightedFMeasure', 'value': 1.0},
#      {'name': 'weightedRecall', 'value': 1.0},
#      {'name': 'weightedFalsePositiveRate', 'value': None},
#      {'name': 'weightedPrecision', 'value': 1.0}],
#     'quality': 1.0,
#     'threshold': 0.8}}],
#  'start': '2019-02-14T11:50:55.426Z'}

# %% [markdown]
# <a id="datamart"></a>
# ## 6. Explainability

# %%
subscription.payload_logging.show_table()
# Out:
# <HTML>
#         <body>
#             <h3>Payload_0530ab0cd4f4dd5486b19c08df8b6914 (binding_id=d47e97b7-07d7-4874-b604-e47ff1a0cd26, subscription_id=0530ab0cd4f4dd5486b19c08df8b6914)</h3>
#             <table style='border: 1px solid #dddddd; font-family: Courier'>
#                 <th style='border: 1px solid #dddddd'>scoring_id</th><th style='border: 1px solid #dddddd'>scoring_timestamp</th><th style='border: 1px solid #dddddd'>deployment_id</th><th style='border: 1px solid #dddddd'>asset_revision</th><th style='border: 1px solid #dddddd'>radius_mean</th><th style='border: 1px solid #dddddd'>texture_mean</th><th style='border: 1px solid #dddddd'>perimeter_mean</th><th style='border: 1px solid #dddddd'>area_mean</th><th style='border: 1px solid #dddddd'>smoothness_mean</th><th style='border: 1px solid #dddddd'>compactness_mean</th><th style='border: 1px solid #dddddd'>concavity_mean</th><th style='border: 1px solid #dddddd'>concave points_mean</th><th style='border: 1px solid #dddddd'>symmetry_mean</th><th style='border: 1px solid #dddddd'>fractal_dimension_mean</th><th style='border: 1px solid #dddddd'>radius_se</th><th style='border: 1px solid #dddddd'>texture_se</th><th style='border: 1px solid #dddddd'>perimeter_se</th><th style='border: 1px solid #dddddd'>area_se</th><th style='border: 1px solid #dddddd'>smoothness_se</th><th style='border: 1px solid #dddddd'>compactness_se</th><th style='border: 1px solid #dddddd'>concavity_se</th><th style='border: 1px solid #dddddd'>concave points_se</th><th style='border: 1px solid #dddddd'>symmetry_se</th><th style='border: 1px solid #dddddd'>fractal_dimension_se</th><th style='border: 1px solid #dddddd'>radius_worst</th><th style='border: 1px solid #dddddd'>texture_worst</th><th style='border: 1px solid #dddddd'>perimeter_worst</th><th style='border: 1px solid #dddddd'>area_worst</th><th style='border: 1px solid #dddddd'>smoothness_worst</th><th style='border: 1px solid #dddddd'>compactness_worst</th><th style='border: 1px solid #dddddd'>concavity_worst</th><th style='border: 1px solid #dddddd'>concave points_worst</th><th style='border: 1px solid #dddddd'>symmetry_worst</th><th style='border: 1px solid #dddddd'>fractal_dimension_worst</th><th style='border: 1px solid #dddddd'>score</th><th style='border: 1px solid #dddddd'>predicted_label</th>
#                 <tr><td style='border: 1px solid #dddddd'>33a30b30-6526-4e58-9dae-72eab044a022-1</td><td style='border: 1px solid #dddddd'>2019-02-14 12:57:48.299540+00:00</td><td style='border: 1px solid #dddddd'>37a83f399e6dc3b9d08d7d01fe690665</td><td style='border: 1px solid #dddddd'>None</td><td style='border: 1px solid #dddddd'>17.02</td><td style='border: 1px solid #dddddd'>23.98</td><td style='border: 1px solid #dddddd'>112.8</td><td style='border: 1px solid #dddddd'>899.3</td><td style='border: 1px solid #dddddd'>0.1197</td><td style='border: 1px solid #dddddd'>0.1496</td><td style='border: 1px solid #dddddd'>0.2417</td><td style='border: 1px solid #dddddd'>0.1203</td><td style='border: 1px solid #dddddd'>0.2248</td><td style='border: 1px solid #dddddd'>0.06382</td><td style='border: 1px solid #dddddd'>0.6009</td><td style='border: 1px solid #dddddd'>1.398</td><td style='border: 1px solid #dddddd'>3.999</td><td style='border: 1px solid #dddddd'>67.78</td><td style='border: 1px solid #dddddd'>0.008268</td><td style='border: 1px solid #dddddd'>0.03082</td><td style='border: 1px solid #dddddd'>0.05042</td><td style='border: 1px solid #dddddd'>0.01112</td><td style='border: 1px solid #dddddd'>0.02102</td><td style='border: 1px solid #dddddd'>0.003854</td><td style='border: 1px solid #dddddd'>20.88</td><td style='border: 1px solid #dddddd'>32.09</td><td style='border: 1px solid #dddddd'>136.1</td><td style='border: 1px solid #dddddd'>1344.0</td><td style='border: 1px solid #dddddd'>0.1634</td><td style='border: 1px solid #dddddd'>0.3559</td><td style='border: 1px solid #dddddd'>0.5588</td><td style='border: 1px solid #dddddd'>0.1847</td><td style='border: 1px solid #dddddd'>0.353</td><td style='border: 1px solid #dddddd'>0.08482</td><td style='border: 1px solid #dddddd'>[5.532644564709699e-09, 1.0]</td><td style='border: 1px solid #dddddd'>1.0</td></tr><tr><td style='border: 1px solid #dddddd'>33a30b30-6526-4e58-9dae-72eab044a022-2</td><td style='border: 1px solid #dddddd'>2019-02-14 12:57:48.299540+00:00</td><td style='border: 1px solid #dddddd'>37a83f399e6dc3b9d08d7d01fe690665</td><td style='border: 1px solid #dddddd'>None</td><td style='border: 1px solid #dddddd'>17.02</td><td style='border: 1px solid #dddddd'>23.98</td><td style='border: 1px solid #dddddd'>112.8</td><td style='border: 1px solid #dddddd'>899.3</td><td style='border: 1px solid #dddddd'>0.1197</td><td style='border: 1px solid #dddddd'>0.1496</td><td style='border: 1px solid #dddddd'>0.2417</td><td style='border: 1px solid #dddddd'>0.1203</td><td style='border: 1px solid #dddddd'>0.2248</td><td style='border: 1px solid #dddddd'>0.06382</td><td style='border: 1px solid #dddddd'>0.6009</td><td style='border: 1px solid #dddddd'>1.398</td><td style='border: 1px solid #dddddd'>3.999</td><td style='border: 1px solid #dddddd'>67.78</td><td style='border: 1px solid #dddddd'>0.008268</td><td style='border: 1px solid #dddddd'>0.03082</td><td style='border: 1px solid #dddddd'>0.05042</td><td style='border: 1px solid #dddddd'>0.01112</td><td style='border: 1px solid #dddddd'>0.02102</td><td style='border: 1px solid #dddddd'>0.003854</td><td style='border: 1px solid #dddddd'>20.88</td><td style='border: 1px solid #dddddd'>32.09</td><td style='border: 1px solid #dddddd'>136.1</td><td style='border: 1px solid #dddddd'>1344.0</td><td style='border: 1px solid #dddddd'>0.1634</td><td style='border: 1px solid #dddddd'>0.3559</td><td style='border: 1px solid #dddddd'>0.5588</td><td style='border: 1px solid #dddddd'>0.1847</td><td style='border: 1px solid #dddddd'>0.353</td><td style='border: 1px solid #dddddd'>0.08482</td><td style='border: 1px solid #dddddd'>[5.532644564709699e-09, 1.0]</td><td style='border: 1px solid #dddddd'>1.0</td></tr><tr><td style='border: 1px solid #dddddd'>c037d27e-b442-4f86-827e-d1a5b346700f-1</td><td style='border: 1px solid #dddddd'>2019-02-14 12:57:48.299505+00:00</td><td style='border: 1px solid #dddddd'>37a83f399e6dc3b9d08d7d01fe690665</td><td ...

# %% [markdown]
# ### Run explainability

# %%
sample_transaction_id = subscription.payload_logging.get_table_content(limit=1)['scoring_id'][0]

run_details = subscription.explainability.run(transaction_id=sample_transaction_id, background_mode=False)
# Out:
# ====================================================================
#
#  Looking for explanation for 33a30b30-6526-4e58-9dae-72eab044a022-1
#
# ====================================================================
#
#
#
# in_progress......
# finished
#
# ---------------------------
#  Successfully finished run
# ---------------------------

# %%
import json

print(json.dumps(run_details['entity']['contrastive_explanation'], indent=2))
# Out:
# {
#   "is_pn_closest_point_to_pp": true,
#   "pertinent_negative_features": [
#     {
#       "feature_name": "concavity_worst",
#       "importance": "0.02350630478235246",
#       "feature_value": "0.23160"
#     },
#     {
#       "feature_name": "radius_mean",
#       "importance": "0.0",
#       "feature_value": "13.37"
#     },
#     {
#       "feature_name": "texture_mean",
#       "importance": "0.0",
#       "feature_value": "18.84"
#     },
#     {
#       "feature_name": "perimeter_mean",
#       "importance": "0.0",
#       "feature_value": "86.24"
#     },
#     {
#       "feature_name": "area_mean",
#       "importance": "0.0",
#       "feature_value": "551.1"
#     },
#     {
#       "feature_name": "smoothness_mean",
#       "importance": "0.0",
#       "feature_value": "0.09587"
#     },
#     {
#       "feature_name": "compactness_mean",
#       "importance": "0.0",
#       "feature_value": "0.09263"
#     },
#     {
#       "feature_name": "concavity_mean",
#       "importance": "0.0",
#       "feature_value": "0.06154"
#     },
#     {
#       "feature_name": "concave points_mean",
#       "importance": "0.0",
#       "feature_value": "0.0335"
#     },
#     {
#       "feature_name": "symmetry_mean",
#       "importance": "0.0",
#       "feature_value": "0.1792"
#     },
#     {
#       "feature_name": "fractal_dimension_mean",
#       "importance": "0.0",
#       "feature_value": "0.06154"
#     },
#     {
#       "feature_name": "radius_se",
#       "importance": "0.0",
#       "feature_value": "0.3242"
#     },
#     {
#       "feature_name": "texture_se",
#       "importance": "0.0",
#       "feature_value": "1.10800"
#     },
#     {
#       "feature_name": "perimeter_se",
#       "importance": "0.0",
#       "feature_value": "2.287"
#     },
#     {
#       "feature_name": "area_se",
#       "importance": "0.0",
#       "feature_value": "24.53"
#     },
#     {
#       "feature_name": "smoothness_se",
#       "importance": "0.0",
#       "feature_value": "0.00638"
#     },
#     {
#       "feature_name": "compactness_se",
#       "importance": "0.0",
#       "feature_value": "0.02045"
#     },
#     {
#       "feature_name": "concavity_se",
#       "importance": "0.0",
#       "feature_value": "0.02589"
#     },
#     {
#       "feature_name": "concave points_se",
#       "importance": "0.0",
#       "feature_value": "0.01093"
#     },
#     {
#       "feature_name": "symmetry_se",
#       "importance": "0.0",
#       "feature_value": "0.01873"
#     },
#     {
#       "feature_name": "fractal_dimension_se",
#       "importance": "0.0",
#       "feature_value": "0.00319"
#     },
#     {
#       "feature_name": "radius_worst",
#       "importance": "0.0",
#       "feature_value": "14.97"
#     },
#     {
#       "feature_name": "texture_worst",
#       "importance": "0.0",
#       "feature_value": "25.41"
#     },
#     {
#       "feature_name": "perimeter_worst",
#       "importance": "0.0",
#       "feature_value": "97.66"
#     },
#     {
#       "feature_name": "area_worst",
#       "importance": "0.0",
#       "feature_value": "686.5"
#     },
#     {
#       "feature_name": "smoothness_worst",
#       "importance": "0.0",
#       "feature_value": "0.1313"
#     },
#     {
#       "feature_name": "compactness_worst",
#       "importance": "0.0",
#       "feature_value": "0.2119"
#     },
#     {
#       "feature_name": "concave points_worst",
#       "importance": "0.0",
#       "feature_value": "0.09993"
#     },
#     {
#       "feature_name": "symmetry_worst",
#       "importance": "0.0",
#       "feature_value": "0.2822"
#     },
#     {
#       "feature_name": "fractal_dimension_worst",
#       "importance": "0.0",
#       "feature_value": "0.08004"
#     }
#   ],
#   "pertinent_positive_features": [
#     {
#       "feature_name": "concavity_mean",
#       "importance": "2.2619035937325496",
#       "feature_value": "0.24170"
#     },
#     {
#       "feature_name": "concave points_mean",
#       "importance": "2.238917666092252",
#       "feature_value": "0.1203"
#     },
#     {
#       "feature_name": "smoothness_mean",
#       "importance": "1.695872481709044",
#       "feature_value": "0.11970"
#     },
#     {
#       "feature_name": "symmetry_mean",
#       "importance": "1.6648301895474824",
#       "feature_value": "0.2248"
#     },
#     {
#       "feature_name": "concave points_worst",
#       "importance": "1.2907586603507508",
#       "feature_value": "0.18470"
#     },
#     {
#       "feature_name": "concavity_se",
#       "importance": "0.8133417727062966",
#       "feature_value": "0.05042"
#     },
#     {
#       "feature_name": "fractal_dimension_worst",
#       "importance": "0.26488760748006146",
#       "feature_value": "0.08482"
#     },
#     {
#       "feature_name": "concave points_se",
#       "importance": "0.03081983645919996",
#       "feature_value": "0.01112"
#     },
#     {
#       "feature_name": "radius_mean",
#       "importance": "0.0",
#       "feature_value": "13.37"
#     },
#     {
#       "feature_name": "texture_mean",
#       "importance": "0.0",
#       "feature_value": "18.84"
#     },
#     {
#       "feature_name": "perimeter_mean",
#       "importance": "0.0",
#       "feature_value": "86.24"
#     },
#     {
#       "feature_name": "area_mean",
#       "importance": "0.0",
#       "feature_value": "551.1"
#     },
#     {
#       "feature_name": "compactness_mean",
#       "importance": "0.0",
#       "feature_value": "0.09263"
#     },
#     {
#       "feature_name": "fractal_dimension_mean",
#       "importance": "0.0",
#       "feature_value": "0.06154"
#     },
#     {
#       "feature_name": "radius_se",
#       "importance": "0.0",
#       "feature_value": "0.3242"
#     },
#     {
#       "feature_name": "texture_se",
#       "importance": "0.0",
#       "feature_value": "1.10800"
#     },
#     {
#       "feature_name": "perimeter_se",
#       "importance": "0.0",
#       "feature_value": "2.287"
#     },
#     {
#       "feature_name": "area_se",
#       "importance": "0.0",
#       "feature_value": "24.53"
#     },
#     {
#       "feature_name": "smoothness_se",
#       "importance": "0.0",
#       "feature_value": "0.00638"
#     },
#     {
#       "feature_name": "compactness_se",
#       "importance": "0.0",
#       "feature_value": "0.02045"
#     },
#     {
#       "feature_name": "symmetry_se",
#       "importance": "0.0",
#       "feature_value": "0.01873"
#     },
#     {
#       "feature_name": "fractal_dimension_se",
#       "importance": "0.0",
#       "feature_value": "0.00319"
#     },
#     {
#       "feature_name": "radius_worst",
#       "importance": "0.0",
#       "feature_value": "14.97"
#     },
#     {
#       "feature_name": "texture_worst",
#       "importance": "0.0",
#       "feature_value": "25.41"
#     },
#     {
#       "feature_name": "perimeter_worst",
#       "importance": "0.0",
#       "feature_value": "97.66"
#     },
#     {
#       "feature_name": "area_worst",
#       "importance": "0.0",
#       "feature_value": "686.5"
#     },
#     {
#       "feature_name": "smoothness_worst",
#       "importance": "0.0",
#       "feature_value": "0.1313"
#     },
#     {
#       "feature_name": "compactness_worst",
#       "importance": "0.0",
#       "feature_value": "0.2119"
#     },
#     {
#       "feature_name": "concavity_worst",
#       "importance": "0.0",
#       "feature_value": "0.22670"
#     },
#     {
#       "feature_name": "symmetry_worst",
#       "importance": "0.0",
#       "feature_value": "0.2822"
#     }
#   ]
# }

# %% [markdown]
# ---

# %% [markdown]
# ### Authors
# Lukasz Cmielowski, PhD, is an Automation Architect and Data Scientist at IBM with a track record of developing enterprise-level applications that substantially increases clients' ability to turn data into actionable knowledge.
